# %% [markdown]
# # Magma - Distinct Input, Distinct Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from kernax import DiagKernel, ExpKernel
from MagmaClustPy.custom_kernels import SEMagmaKernel
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, Magma
# Out:
# INFO:2025-12-17 13:28:05,348:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2025-12-17 13:28:05,348 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %%
db = pd.read_csv(f"../../datasets/K=1/{test_db_size}_distinct_input_distinct_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kernel = SEMagmaKernel(length_scale=.3, variance=1.)
task_kernel_train = SEMagmaKernel(length_scale=.6, variance=1.) + DiagKernel(ExpKernel(2.5))
task_kernel_pred = deepcopy(task_kernel_train)

prior_mean = ZeroMean()

likelihood = BaseLikelihood()

# %%
model = Magma(likelihood=likelihood, prior_mean=prior_mean, mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=False)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2025-12-17 13:28:06,742 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.30, variance=1.00)
# 	Task kernel: SEMagmaKernel(length_scale=[0.60 ± 0.00]₁₆, variance=[1.00 ± 0.00]₁₆) + Diag(Exp([2.50 ± 0.00]₁₆))
# 2025-12-17 13:28:47,425 - INFO - Iteration    1	Llhs:   -4072.2178,     645.1731	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=1.42, variance=1.71)
# 	Task kernel: SEMagmaKernel(length_scale=[1.06 ± 0.73]₁₆, variance=[3.15 ± 0.70]₁₆) + Diag(Exp([-1.86 ± 2.08]₁₆))
# 2025-12-17 13:28:57,703 - INFO - Iteration    2	Llhs:   -3860.1500,     621.4479	Conv. Ratio: 0.05496
# 	Mean kernel: SEMagmaKernel(length_scale=1.42, variance=1.71)
# 	Task kernel: SEMagmaKernel(length_scale=[0.98 ± 0.69]₁₆, variance=[3.01 ± 0.46]₁₆) + Diag(Exp([-2.22 ± 2.00]₁₆))
# 2025-12-17 13:29:10,526 - INFO - Iteration    3	Llhs:   -6013.9446,     614.2767	Conv. Ratio: 0.66723
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.96 ± 0.67]₁₆, variance=[2.92 ± 0.44]₁₆) + Diag(Exp([-2.20 ± 1.94]₁₆))
# 2025-12-17 13:29:21,792 - INFO - Iteration    4	Llhs:   -5587.5342,     603.6397	Conv. Ratio: 0.07700
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.74 ± 0.60]₁₆, variance=[2.69 ± 0.46]₁₆) + Diag(Exp([-2.81 ± 2.32]₁₆))
# 2025-12-17 13:29:34,407 - INFO - Iteration    5	Llhs:   -5217.5694,     591.9239	Conv. Ratio: 0.07188
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.60 ± 0.58]₁₆, variance=[2.49 ± 0.50]₁₆) + Diag(Exp([-3.05 ± 2.31]₁₆))
# 2025-12-17 13:29:44,891 - INFO - Iteration    6	Llhs:   -4968.9395,     583.0351	Conv. Ratio: 0.05183
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.49 ± 0.59]₁₆, variance=[2.36 ± 0.51]₁₆) + Diag(Exp([-3.15 ± 2.26]₁₆))
# 2025-12-17 13:29:55,240 - INFO - Iteration    7	Llhs:   -4803.2407,     576.8219	Conv. Ratio: 0.03636
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.44 ± 0.58]₁₆, variance=[2.28 ± 0.51]₁₆) + Diag(Exp([-3.17 ± 2.25]₁₆))
# 2025-12-17 13:30:05,035 - INFO - Iteration    8	Llhs:   -4716.9839,     573.3771	Conv. Ratio: 0.01959
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.42 ± 0.57]₁₆, variance=[2.23 ± 0.52]₁₆) + Diag(Exp([-3.19 ± 2.25]₁₆))
# 2025-12-17 13:30:15,391 - INFO - Iteration    9	Llhs:   -4672.6395,     571.5664	Conv. Ratio: 0.01026
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.41 ± 0.57]₁₆, variance=[2.21 ± 0.52]₁₆) + Diag(Exp([-3.19 ± 2.25]₁₆))
# 2025-12-17 13:30:25,018 - INFO - Iteration   10	Llhs:   -4651.7281,     570.6896	Conv. Ratio: 0.00489
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.41 ± 0.57]₁₆, variance=[2.19 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.25]₁₆))
# 2025-12-17 13:30:35,377 - INFO - Iteration   11	Llhs:   -4639.1934,     570.1786	Conv. Ratio: 0.00295
# 	Mean kernel: SEMagmaKernel(length_scale=1.62, variance=1.85)
# 	Task kernel: SEMagmaKernel(length_scale=[0.41 ± 0.57]₁₆, variance=[2.19 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.25]₁₆))
# 2025-12-17 13:31:01,528 - INFO - Iteration   12	Llhs:   -4748.9057,     570.1223	Conv. Ratio: 0.02698
# 	Mean kernel: SEMagmaKernel(length_scale=1.64, variance=1.86)
# 	Task kernel: SEMagmaKernel(length_scale=[0.41 ± 0.57]₁₆, variance=[2.19 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.25]₁₆))
# 2025-12-17 13:31:19,025 - INFO - Iteration   13	Llhs:   -4836.6246,     570.0789	Conv. Ratio: 0.02100
# 	Mean kernel: SEMagmaKernel(length_scale=1.64, variance=1.86)
# 	Task kernel: SEMagmaKernel(length_scale=[0.40 ± 0.57]₁₆, variance=[2.18 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.25]₁₆))
# 2025-12-17 13:31:27,841 - INFO - Iteration   14	Llhs:   -4825.6536,     569.7542	Conv. Ratio: 0.00250
# 	Mean kernel: SEMagmaKernel(length_scale=1.64, variance=1.86)
# 	Task kernel: SEMagmaKernel(length_scale=[0.40 ± 0.57]₁₆, variance=[2.18 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.24]₁₆))
# 2025-12-17 13:31:28,802 - INFO - Convergence reached after 15 iterations.	NLLs:   -4825.2977,     569.7319
# 	Mean kernel: SEMagmaKernel(length_scale=1.64, variance=1.86)
# 	Task kernel: SEMagmaKernel(length_scale=[0.40 ± 0.57]₁₆, variance=[2.18 ± 0.52]₁₆) + Diag(Exp([-3.20 ± 2.24]₁₆))

# %%
grid = model.generate_grid(grid_size)
grid.shape
# Out:
# (250, 1)

# %%
mean_pred, mean_cov = model.predict(grid)
mean_pred.shape, mean_cov.shape
# Out:
# ((4, 291), (4, 291, 291))

# %%
model.plot_mean_process()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %%
model.plot_predictions(plot_as="samples", task_id=0, nb_samples=50)
plt.show()

# %% [markdown]
# ---
