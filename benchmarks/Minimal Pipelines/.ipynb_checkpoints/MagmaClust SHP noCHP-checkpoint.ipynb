# %% [markdown]
# # MagmaClust - Distinct Input, Shared Hyperparameters, no Cluster Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from kernax import DiagKernel, ExpKernel
from MagmaClustPy.custom_kernels import SEMagmaKernel
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, MagmaClust
# Out:
# INFO:2025-12-17 13:36:00,483:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2025-12-17 13:36:00,483 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %% [markdown]
# ##### Setup

# %%
db = pd.read_csv(f"../../datasets/K={nb_cluster}/{test_db_size}_distinct_input_shared_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kern = SEMagmaKernel(length_scale=.2, variance=5.)
task_kern = SEMagmaKernel(length_scale=.2, variance=1.) + DiagKernel(ExpKernel(2.5))

# %%
model = MagmaClust(k=nb_cluster, likelihood=BaseLikelihood(), prior_mean=ZeroMean(), mean_kernel=mean_kern, task_kernel_train=task_kern, task_kernel_pred=deepcopy(task_kern), shared_hp=True, cluster_hp=False)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2025-12-17 13:36:01,863 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.20, variance=5.00)
# 	Task kernel: SEMagmaKernel(length_scale=0.20, variance=1.00) + Diag(Exp(2.50))
# 2025-12-17 13:36:03,411 - INFO - Iteration    1	Llhs:     244.9715,     675.2237	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.33, variance=6.02)
# 	Task kernel: SEMagmaKernel(length_scale=-0.64, variance=2.06) + Diag(Exp(-3.32))
# 2025-12-17 13:36:04,687 - INFO - Iteration    2	Llhs:     232.4694,     586.6118	Conv. Ratio: 0.10988
# 	Mean kernel: SEMagmaKernel(length_scale=0.38, variance=6.10)
# 	Task kernel: SEMagmaKernel(length_scale=-0.28, variance=1.70) + Diag(Exp(-2.85))
# 2025-12-17 13:36:04,722 - INFO - Iteration    3	Llhs:     217.0415,     539.4541	Conv. Ratio: 0.07641
# 	Mean kernel: SEMagmaKernel(length_scale=0.43, variance=6.09)
# 	Task kernel: SEMagmaKernel(length_scale=-0.01, variance=1.58) + Diag(Exp(-2.79))
# 2025-12-17 13:36:04,779 - INFO - Iteration    4	Llhs:     202.9138,     515.3190	Conv. Ratio: 0.05058
# 	Mean kernel: SEMagmaKernel(length_scale=0.47, variance=6.09)
# 	Task kernel: SEMagmaKernel(length_scale=0.16, variance=1.55) + Diag(Exp(-2.82))
# 2025-12-17 13:36:04,819 - INFO - Iteration    5	Llhs:     190.6215,     504.3182	Conv. Ratio: 0.03243
# 	Mean kernel: SEMagmaKernel(length_scale=0.51, variance=6.13)
# 	Task kernel: SEMagmaKernel(length_scale=0.25, variance=1.55) + Diag(Exp(-2.83))
# 2025-12-17 13:36:04,855 - INFO - Iteration    6	Llhs:     180.1229,     500.1088	Conv. Ratio: 0.02116
# 	Mean kernel: SEMagmaKernel(length_scale=0.55, variance=6.13)
# 	Task kernel: SEMagmaKernel(length_scale=0.29, variance=1.56) + Diag(Exp(-2.83))
# 2025-12-17 13:36:04,895 - INFO - Iteration    7	Llhs:     171.0939,     499.0125	Conv. Ratio: 0.01489
# 	Mean kernel: SEMagmaKernel(length_scale=0.58, variance=6.17)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.56) + Diag(Exp(-2.80))
# 2025-12-17 13:36:04,938 - INFO - Iteration    8	Llhs:     163.3767,     499.2334	Conv. Ratio: 0.01119
# 	Mean kernel: SEMagmaKernel(length_scale=0.61, variance=6.16)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.77))
# 2025-12-17 13:36:04,979 - INFO - Iteration    9	Llhs:     156.6695,     500.0128	Conv. Ratio: 0.00895
# 	Mean kernel: SEMagmaKernel(length_scale=0.63, variance=6.16)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.74))
# 2025-12-17 13:36:05,019 - INFO - Iteration   10	Llhs:     150.7556,     501.0101	Conv. Ratio: 0.00749
# 	Mean kernel: SEMagmaKernel(length_scale=0.66, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.71))
# 2025-12-17 13:36:05,051 - INFO - Iteration   11	Llhs:     145.6903,     502.0370	Conv. Ratio: 0.00620
# 	Mean kernel: SEMagmaKernel(length_scale=0.67, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.68))
# 2025-12-17 13:36:05,084 - INFO - Iteration   12	Llhs:     141.1771,     503.0646	Conv. Ratio: 0.00538
# 	Mean kernel: SEMagmaKernel(length_scale=0.69, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.65))
# 2025-12-17 13:36:05,120 - INFO - Iteration   13	Llhs:     137.1903,     504.0544	Conv. Ratio: 0.00465
# 	Mean kernel: SEMagmaKernel(length_scale=0.71, variance=6.25)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.56) + Diag(Exp(-2.63))
# 2025-12-17 13:36:05,163 - INFO - Iteration   14	Llhs:     133.7078,     504.9589	Conv. Ratio: 0.00402
# 	Mean kernel: SEMagmaKernel(length_scale=0.72, variance=6.25)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.55) + Diag(Exp(-2.61))
# 2025-12-17 13:36:05,205 - INFO - Iteration   15	Llhs:     130.5700,     505.8221	Conv. Ratio: 0.00356
# 	Mean kernel: SEMagmaKernel(length_scale=0.73, variance=6.25)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.55) + Diag(Exp(-2.60))
# 2025-12-17 13:36:05,255 - INFO - Iteration   16	Llhs:     127.8447,     506.6266	Conv. Ratio: 0.00302
# 	Mean kernel: SEMagmaKernel(length_scale=0.75, variance=6.28)
# 	Task kernel: SEMagmaKernel(length_scale=0.32, variance=1.55) + Diag(Exp(-2.57))
# 2025-12-17 13:36:05,286 - INFO - Iteration   17	Llhs:     125.4375,     507.3200	Conv. Ratio: 0.00270
# 	Mean kernel: SEMagmaKernel(length_scale=0.75, variance=6.28)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.57))
# 2025-12-17 13:36:05,322 - INFO - Iteration   18	Llhs:     123.2997,     507.9735	Conv. Ratio: 0.00235
# 	Mean kernel: SEMagmaKernel(length_scale=0.76, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.54))
# 2025-12-17 13:36:05,351 - INFO - Iteration   19	Llhs:     121.4284,     508.5287	Conv. Ratio: 0.00208
# 	Mean kernel: SEMagmaKernel(length_scale=0.77, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.54))
# 2025-12-17 13:36:05,385 - INFO - Iteration   20	Llhs:     119.8001,     509.0484	Conv. Ratio: 0.00176
# 	Mean kernel: SEMagmaKernel(length_scale=0.78, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.53))
# 2025-12-17 13:36:05,419 - INFO - Iteration   21	Llhs:     118.4061,     509.5187	Conv. Ratio: 0.00147
# 	Mean kernel: SEMagmaKernel(length_scale=0.78, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.51))
# 2025-12-17 13:36:05,464 - INFO - Iteration   22	Llhs:     117.1857,     509.8995	Conv. Ratio: 0.00134
# 	Mean kernel: SEMagmaKernel(length_scale=0.79, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.31, variance=1.55) + Diag(Exp(-2.50))
# 2025-12-17 13:36:05,488 - INFO - Iteration   23	Llhs:     116.1592,     510.2520	Conv. Ratio: 0.00107
# 	Mean kernel: SEMagmaKernel(length_scale=0.79, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.30, variance=1.55) + Diag(Exp(-2.50))
# 2025-12-17 13:36:05,516 - INFO - Convergence reached after 24 iterations.	NLLs:     115.2900,     510.5792
# 	Mean kernel: SEMagmaKernel(length_scale=0.79, variance=6.30)
# 	Task kernel: SEMagmaKernel(length_scale=0.30, variance=1.55) + Diag(Exp(-2.49))

# %%
grid = model.generate_grid(grid_size)
grid.shape
# Out:
# (250, 1)

# %%
pred_means, pred_covs = model.predict(grid)
pred_means.shape, pred_covs.shape
# Out:
# ((4, 4, 291), (4, 4, 291, 291))

# %% [markdown]
# ##### Test

# %%
model.plot_mean_processes()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()
