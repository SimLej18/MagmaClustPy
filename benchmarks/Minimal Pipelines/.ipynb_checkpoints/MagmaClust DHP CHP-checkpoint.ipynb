# %% [markdown]
# # MagmaClust - Distinct Input, Distinct Hyperparameters, Cluster Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from kernax import DiagKernel, ExpKernel
from MagmaClustPy.custom_kernels import SEMagmaKernel
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, MagmaClust
# Out:
# INFO:2025-12-17 13:38:43,202:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2025-12-17 13:38:43,202 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %% [markdown]
# ##### Setup

# %%
db = pd.read_csv(f"../../datasets/K={nb_cluster}/{test_db_size}_distinct_input_distinct_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kern = SEMagmaKernel(length_scale=.2, variance=5.)
task_kern = SEMagmaKernel(length_scale=.2, variance=1.) + DiagKernel(ExpKernel(2.5))

# %%
model = MagmaClust(k=nb_cluster, likelihood=BaseLikelihood(), prior_mean=ZeroMean(), mean_kernel=mean_kern, task_kernel_train=task_kern, task_kernel_pred=deepcopy(task_kern), shared_hp=False, cluster_hp=True)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2025-12-17 13:38:44,700 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.20, variance=5.00)
# 	Task kernel: SEMagmaKernel(length_scale=[0.20 ± 0.00]₄ₓ₁₆, variance=[1.00 ± 0.00]₄ₓ₁₆) + Diag(Exp([2.50 ± 0.00]₄ₓ₁₆))
# 2025-12-17 13:38:46,218 - INFO - Iteration    1	Llhs:     272.1984,    4988.9343	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.36, variance=6.54)
# 	Task kernel: SEMagmaKernel(length_scale=[2.51 ± 2.63]₄ₓ₁₆, variance=[5.11 ± 2.69]₄ₓ₁₆) + Diag(Exp([3.09 ± 4.22]₄ₓ₁₆))
# 2025-12-17 13:38:47,494 - INFO - Iteration    2	Llhs:     260.6346,    4753.7230	Conv. Ratio: 0.04691
# 	Mean kernel: SEMagmaKernel(length_scale=0.39, variance=6.58)
# 	Task kernel: SEMagmaKernel(length_scale=[2.55 ± 2.35]₄ₓ₁₆, variance=[5.82 ± 2.74]₄ₓ₁₆) + Diag(Exp([2.18 ± 4.42]₄ₓ₁₆))
# 2025-12-17 13:38:47,779 - INFO - Iteration    3	Llhs:     248.1357,    4351.3925	Conv. Ratio: 0.08273
# 	Mean kernel: SEMagmaKernel(length_scale=0.43, variance=6.58)
# 	Task kernel: SEMagmaKernel(length_scale=[3.08 ± 2.40]₄ₓ₁₆, variance=[6.58 ± 2.84]₄ₓ₁₆) + Diag(Exp([1.24 ± 4.25]₄ₓ₁₆))
# 2025-12-17 13:38:47,913 - INFO - Iteration    4	Llhs:     236.7662,    4268.0107	Conv. Ratio: 0.02060
# 	Mean kernel: SEMagmaKernel(length_scale=0.46, variance=6.57)
# 	Task kernel: SEMagmaKernel(length_scale=[3.14 ± 2.37]₄ₓ₁₆, variance=[6.48 ± 2.88]₄ₓ₁₆) + Diag(Exp([1.17 ± 4.24]₄ₓ₁₆))
# 2025-12-17 13:38:48,040 - INFO - Iteration    5	Llhs:     228.3597,    4212.6343	Conv. Ratio: 0.01416
# 	Mean kernel: SEMagmaKernel(length_scale=0.50, variance=6.62)
# 	Task kernel: SEMagmaKernel(length_scale=[3.16 ± 2.34]₄ₓ₁₆, variance=[6.43 ± 2.95]₄ₓ₁₆) + Diag(Exp([1.13 ± 4.21]₄ₓ₁₆))
# 2025-12-17 13:38:48,172 - INFO - Iteration    6	Llhs:     221.9485,    4178.1507	Conv. Ratio: 0.00921
# 	Mean kernel: SEMagmaKernel(length_scale=0.52, variance=6.62)
# 	Task kernel: SEMagmaKernel(length_scale=[3.17 ± 2.33]₄ₓ₁₆, variance=[6.39 ± 3.02]₄ₓ₁₆) + Diag(Exp([1.10 ± 4.19]₄ₓ₁₆))
# 2025-12-17 13:38:48,261 - INFO - Iteration    7	Llhs:     217.3361,    4157.0143	Conv. Ratio: 0.00585
# 	Mean kernel: SEMagmaKernel(length_scale=0.54, variance=6.66)
# 	Task kernel: SEMagmaKernel(length_scale=[3.17 ± 2.34]₄ₓ₁₆, variance=[6.36 ± 3.06]₄ₓ₁₆) + Diag(Exp([1.08 ± 4.19]₄ₓ₁₆))
# 2025-12-17 13:38:48,350 - INFO - Iteration    8	Llhs:     214.5573,    4144.3028	Conv. Ratio: 0.00354
# 	Mean kernel: SEMagmaKernel(length_scale=0.55, variance=6.66)
# 	Task kernel: SEMagmaKernel(length_scale=[3.17 ± 2.33]₄ₓ₁₆, variance=[6.34 ± 3.09]₄ₓ₁₆) + Diag(Exp([1.07 ± 4.20]₄ₓ₁₆))
# 2025-12-17 13:38:48,407 - INFO - Iteration    9	Llhs:     213.0233,    4136.6356	Conv. Ratio: 0.00211
# 	Mean kernel: SEMagmaKernel(length_scale=0.55, variance=6.66)
# 	Task kernel: SEMagmaKernel(length_scale=[3.18 ± 2.33]₄ₓ₁₆, variance=[6.34 ± 3.10]₄ₓ₁₆) + Diag(Exp([1.06 ± 4.20]₄ₓ₁₆))
# 2025-12-17 13:38:48,473 - INFO - Iteration   10	Llhs:     212.2857,    4131.8783	Conv. Ratio: 0.00126
# 	Mean kernel: SEMagmaKernel(length_scale=0.55, variance=6.66)
# 	Task kernel: SEMagmaKernel(length_scale=[3.18 ± 2.32]₄ₓ₁₆, variance=[6.33 ± 3.11]₄ₓ₁₆) + Diag(Exp([1.06 ± 4.20]₄ₓ₁₆))
# 2025-12-17 13:38:48,520 - INFO - Convergence reached after 11 iterations.	NLLs:     211.9347,    4128.8040
# 	Mean kernel: SEMagmaKernel(length_scale=0.56, variance=6.69)
# 	Task kernel: SEMagmaKernel(length_scale=[3.19 ± 2.31]₄ₓ₁₆, variance=[6.33 ± 3.11]₄ₓ₁₆) + Diag(Exp([1.05 ± 4.20]₄ₓ₁₆))

# %%
grid = model.generate_grid(grid_size)
grid.shape
# Out:
# (250, 1)

# %%
pred_means, pred_covs = model.predict(grid)
pred_means.shape, pred_covs.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pred_means, pred_covs = model.predict(grid)
#       2 pred_means.shape, pred_covs.shape
#
# File ~/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/models.py:506, in MagmaClust.predict(self, grid, skip_retrain, jitter)
#     504 if self.cluster_hp:
#     505 	batched_hyperpost = vmap(hyperpost, in_axes=(None, None, None, None, None, None, self.task_kernel_pred.batch_in_axes, None, None, 0))
# --> 506 	self.post_means_pred, self.post_covs_pred = batched_hyperpost(
#     507 		self.padded_inputs_train,
#     508 		self.padded_outputs_train,
#     509 		mappings_train_on_grid,
#     510 		self.grid_pred,
#     511 		jnp.array(0.),
#     512 		self.mean_kernel,
#     513 		self.task_kernel_pred.inner_kernel,
#     514 		False,  # As we use a grid
#     515 		self.shared_hp,
#     516 		self.mixture_train)
#     517 	batched_predict = vmap(predict_single_cluster, in_axes=(0, 0, None, None, None, self.task_kernel_pred.batch_in_axes))
#     518 	self.means_pred, self.covs_pred = batched_predict(self.post_means_pred, self.post_covs_pred, self.padded_outputs_pred, mappings_pred_on_grid, self.grid_pred, self.task_kernel_pred.inner_kernel)
#
#     [... skipping hidden 23 frame]
#
# File ~/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/hyperpost.py:124, in hyperpost(inputs, outputs, mappings, all_inputs, prior_mean, mean_kernel, task_kernel, shared_input, shared_hp, mixture_coeffs)
#     121 	return hyperpost_shared_input(outputs, prior_mean, mean_cov_u, mean_cov_inv, task_covs, mixture_coeffs)
#     123 else:  # No shared input: we have to pad and mapping
# --> 124 	task_covs = task_kernel(inputs)  # Shape: (T, Max_Ni, Max_Ni)
#     126 	return hyperpost_distinct_input(outputs, mappings, all_inputs, prior_mean, mean_cov_u, mean_cov_inv,
#     127 	                                task_covs, mixture_coeffs)
#
#     [... skipping hidden 14 frame]
#
# File /opt/miniconda3/envs/MagmaClustPy/lib/python3.13/site-packages/kernax/WrapperKernels.py:174, in BatchKernel.__call__(self, x1, x2)
#     162 """
#     163 Compute the kernel over batched inputs using vmap.
#     164
#    (...)    170 		Kernel matrix of appropriate shape with batch dimension
#     171 """
#     172 # vmap over the batch dimension of inner_kernel and inputs
#     173 # Each batch element gets its own version of inner_kernel with corresponding hyperparameters
# --> 174 return vmap(
#     175 	lambda kernel, x1, x2: kernel(x1, x2),
#     176 	in_axes=(
#     177 		self.batch_in_axes,
#     178 		self.batch_over_inputs,
#     179 		self.batch_over_inputs if x2 is not None else None,
#     180 	),
#     181 )(self.inner_kernel, x1, x2)
#
#     [... skipping hidden 2 frame]
#
# File /opt/miniconda3/envs/MagmaClustPy/lib/python3.13/site-packages/jax/_src/api.py:1248, in _mapped_axis_size(fn, tree, vals, dims, name)
#    1246   else:
#    1247     msg.append(f"  * some axes ({ct} of them) had size {sz}, e.g. axis {ax} of {ex};\n")
# -> 1248 raise ValueError(''.join(msg)[:-2])
#
# ValueError: vmap got inconsistent sizes for array axes to be mapped:
#   * most axes (3 of them) had size 4, e.g. axis 0 of argument kernel.left_kernel.length_scale of type float64[4];
#   * one axis had size 16: axis 0 of argument x1 of type float64[16,20,1]

# %% [markdown]
# ##### Test

# %%
model.plot_mean_processes()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()
