# %% [markdown]
# # MagmaClust - Distinct Input, Shared Hyperparameters, Cluster Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from kernax import DiagKernel, ExpKernel
from MagmaClustPy.custom_kernels import SEMagmaKernel
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, MagmaClust
# Out:
# INFO:2025-12-17 13:36:46,647:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2025-12-17 13:36:46,647 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %% [markdown]
# ##### Setup

# %%
db = pd.read_csv(f"../../datasets/K={nb_cluster}/{test_db_size}_distinct_input_shared_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kern = SEMagmaKernel(length_scale=.2, variance=5.)
task_kern = SEMagmaKernel(length_scale=.2, variance=1.) + DiagKernel(ExpKernel(2.5))

# %%
model = MagmaClust(k=nb_cluster, likelihood=BaseLikelihood(), prior_mean=ZeroMean(), mean_kernel=mean_kern, task_kernel_train=task_kern, task_kernel_pred=deepcopy(task_kern), shared_hp=True, cluster_hp=True)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2025-12-17 13:36:48,106 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.20, variance=5.00)
# 	Task kernel: SEMagmaKernel(length_scale=[0.20 ± 0.00]₄, variance=[1.00 ± 0.00]₄) + Diag(Exp([2.50 ± 0.00]₄))
# 2025-12-17 13:36:49,501 - INFO - Iteration    1	Llhs:     244.9715,     673.4369	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(length_scale=0.33, variance=6.02)
# 	Task kernel: SEMagmaKernel(length_scale=[-0.69 ± 0.11]₄, variance=[2.04 ± 0.15]₄) + Diag(Exp([-4.48 ± 1.48]₄))
# 2025-12-17 13:36:50,610 - INFO - Iteration    2	Llhs:     232.4945,     584.5074	Conv. Ratio: 0.11042
# 	Mean kernel: SEMagmaKernel(length_scale=0.38, variance=6.10)
# 	Task kernel: SEMagmaKernel(length_scale=[-0.39 ± 0.22]₄, variance=[1.63 ± 0.24]₄) + Diag(Exp([-4.10 ± 1.70]₄))
# 2025-12-17 13:36:50,723 - INFO - Iteration    3	Llhs:     217.1772,     531.0113	Conv. Ratio: 0.08423
# 	Mean kernel: SEMagmaKernel(length_scale=0.43, variance=6.09)
# 	Task kernel: SEMagmaKernel(length_scale=[-0.10 ± 0.30]₄, variance=[1.45 ± 0.38]₄) + Diag(Exp([-3.34 ± 1.25]₄))
# 2025-12-17 13:36:50,789 - INFO - Iteration    4	Llhs:     203.0834,     500.2085	Conv. Ratio: 0.06001
# 	Mean kernel: SEMagmaKernel(length_scale=0.47, variance=6.09)
# 	Task kernel: SEMagmaKernel(length_scale=[0.07 ± 0.32]₄, variance=[1.37 ± 0.48]₄) + Diag(Exp([-3.19 ± 0.93]₄))
# 2025-12-17 13:36:50,877 - INFO - Iteration    5	Llhs:     190.6761,     485.7076	Conv. Ratio: 0.03826
# 	Mean kernel: SEMagmaKernel(length_scale=0.51, variance=6.13)
# 	Task kernel: SEMagmaKernel(length_scale=[0.17 ± 0.30]₄, variance=[1.34 ± 0.52]₄) + Diag(Exp([-3.10 ± 0.76]₄))
# 2025-12-17 13:36:50,938 - INFO - Iteration    6	Llhs:     179.9349,     479.6456	Conv. Ratio: 0.02484
# 	Mean kernel: SEMagmaKernel(length_scale=0.55, variance=6.13)
# 	Task kernel: SEMagmaKernel(length_scale=[0.24 ± 0.27]₄, variance=[1.33 ± 0.54]₄) + Diag(Exp([-3.02 ± 0.66]₄))
# 2025-12-17 13:36:50,991 - INFO - Iteration    7	Llhs:     170.4965,     477.4691	Conv. Ratio: 0.01761
# 	Mean kernel: SEMagmaKernel(length_scale=0.58, variance=6.17)
# 	Task kernel: SEMagmaKernel(length_scale=[0.28 ± 0.25]₄, variance=[1.33 ± 0.54]₄) + Diag(Exp([-2.98 ± 0.63]₄))
# 2025-12-17 13:36:51,030 - INFO - Iteration    8	Llhs:     162.2431,     477.0776	Conv. Ratio: 0.01334
# 	Mean kernel: SEMagmaKernel(length_scale=0.61, variance=6.17)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.24]₄, variance=[1.33 ± 0.53]₄) + Diag(Exp([-2.95 ± 0.65]₄))
# 2025-12-17 13:36:51,065 - INFO - Iteration    9	Llhs:     154.9152,     477.6272	Conv. Ratio: 0.01060
# 	Mean kernel: SEMagmaKernel(length_scale=0.64, variance=6.17)
# 	Task kernel: SEMagmaKernel(length_scale=[0.31 ± 0.24]₄, variance=[1.33 ± 0.53]₄) + Diag(Exp([-2.93 ± 0.65]₄))
# 2025-12-17 13:36:51,106 - INFO - Iteration   10	Llhs:     148.3968,     478.4790	Conv. Ratio: 0.00896
# 	Mean kernel: SEMagmaKernel(length_scale=0.66, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=[0.31 ± 0.24]₄, variance=[1.33 ± 0.52]₄) + Diag(Exp([-2.90 ± 0.66]₄))
# 2025-12-17 13:36:51,145 - INFO - Iteration   11	Llhs:     142.7107,     479.5372	Conv. Ratio: 0.00738
# 	Mean kernel: SEMagmaKernel(length_scale=0.68, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=[0.31 ± 0.25]₄, variance=[1.33 ± 0.52]₄) + Diag(Exp([-2.88 ± 0.66]₄))
# 2025-12-17 13:36:51,174 - INFO - Iteration   12	Llhs:     137.6404,     480.5771	Conv. Ratio: 0.00648
# 	Mean kernel: SEMagmaKernel(length_scale=0.70, variance=6.21)
# 	Task kernel: SEMagmaKernel(length_scale=[0.31 ± 0.25]₄, variance=[1.33 ± 0.51]₄) + Diag(Exp([-2.86 ± 0.66]₄))
# 2025-12-17 13:36:51,238 - INFO - Iteration   13	Llhs:     133.1405,     481.5723	Conv. Ratio: 0.00567
# 	Mean kernel: SEMagmaKernel(length_scale=0.72, variance=6.26)
# 	Task kernel: SEMagmaKernel(length_scale=[0.31 ± 0.26]₄, variance=[1.33 ± 0.51]₄) + Diag(Exp([-2.85 ± 0.67]₄))
# 2025-12-17 13:36:51,269 - INFO - Iteration   14	Llhs:     129.3105,     482.4594	Conv. Ratio: 0.00479
# 	Mean kernel: SEMagmaKernel(length_scale=0.74, variance=6.26)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.27]₄, variance=[1.33 ± 0.50]₄) + Diag(Exp([-2.84 ± 0.67]₄))
# 2025-12-17 13:36:51,311 - INFO - Iteration   15	Llhs:     125.9774,     483.2903	Conv. Ratio: 0.00409
# 	Mean kernel: SEMagmaKernel(length_scale=0.75, variance=6.25)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.27]₄, variance=[1.33 ± 0.50]₄) + Diag(Exp([-2.84 ± 0.67]₄))
# 2025-12-17 13:36:51,351 - INFO - Iteration   16	Llhs:     123.1520,     484.0586	Conv. Ratio: 0.00338
# 	Mean kernel: SEMagmaKernel(length_scale=0.76, variance=6.29)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.28]₄, variance=[1.33 ± 0.50]₄) + Diag(Exp([-2.81 ± 0.66]₄))
# 2025-12-17 13:36:51,383 - INFO - Iteration   17	Llhs:     120.7378,     484.8279	Conv. Ratio: 0.00271
# 	Mean kernel: SEMagmaKernel(length_scale=0.77, variance=6.29)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.28]₄, variance=[1.33 ± 0.50]₄) + Diag(Exp([-2.81 ± 0.66]₄))
# 2025-12-17 13:36:51,420 - INFO - Iteration   18	Llhs:     118.6895,     485.3617	Conv. Ratio: 0.00250
# 	Mean kernel: SEMagmaKernel(length_scale=0.78, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.29]₄, variance=[1.33 ± 0.50]₄) + Diag(Exp([-2.81 ± 0.66]₄))
# 2025-12-17 13:36:51,459 - INFO - Iteration   19	Llhs:     117.0060,     485.8439	Conv. Ratio: 0.00199
# 	Mean kernel: SEMagmaKernel(length_scale=0.79, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.30 ± 0.29]₄, variance=[1.33 ± 0.49]₄) + Diag(Exp([-2.79 ± 0.66]₄))
# 2025-12-17 13:36:51,489 - INFO - Iteration   20	Llhs:     115.5747,     486.2844	Conv. Ratio: 0.00164
# 	Mean kernel: SEMagmaKernel(length_scale=0.79, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.29 ± 0.30]₄, variance=[1.33 ± 0.49]₄) + Diag(Exp([-2.79 ± 0.66]₄))
# 2025-12-17 13:36:51,523 - INFO - Iteration   21	Llhs:     114.4026,     486.6632	Conv. Ratio: 0.00132
# 	Mean kernel: SEMagmaKernel(length_scale=0.80, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.29 ± 0.30]₄, variance=[1.34 ± 0.49]₄) + Diag(Exp([-2.79 ± 0.66]₄))
# 2025-12-17 13:36:51,558 - INFO - Iteration   22	Llhs:     113.4441,     486.9988	Conv. Ratio: 0.00104
# 	Mean kernel: SEMagmaKernel(length_scale=0.80, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.29 ± 0.30]₄, variance=[1.34 ± 0.49]₄) + Diag(Exp([-2.79 ± 0.66]₄))
# 2025-12-17 13:36:51,588 - INFO - Convergence reached after 23 iterations.	NLLs:     112.6573,     487.2909
# 	Mean kernel: SEMagmaKernel(length_scale=0.81, variance=6.31)
# 	Task kernel: SEMagmaKernel(length_scale=[0.29 ± 0.30]₄, variance=[1.34 ± 0.49]₄) + Diag(Exp([-2.79 ± 0.66]₄))

# %%
grid = model.generate_grid(grid_size)
grid.shape
# Out:
# (250, 1)

# %%
pred_means, pred_covs = model.predict(grid)
pred_means.shape, pred_covs.shape
# Out:
# ((4, 4, 291), (4, 4, 291, 291))

# %% [markdown]
# ##### Test

# %%
model.plot_mean_processes()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()
