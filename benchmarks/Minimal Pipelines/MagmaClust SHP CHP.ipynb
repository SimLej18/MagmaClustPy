# %% [markdown]
# # MagmaClust - Distinct Input, Shared Hyperparameters, Cluster Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import kernax
kernax.config.parameter_transform = "softplus"  # Important for the stability of the optimisation
from kernax import WhiteNoiseKernel, SEKernel

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, MagmaClust
# Out:
# INFO:2026-03-02 12:56:28,566:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2026-03-02 12:56:28,566 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %% [markdown]
# ##### Setup

# %%
db = pd.read_csv(f"../../datasets/K={nb_cluster}/{test_db_size}_distinct_input_shared_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kernel = 100. * SEKernel(length_scale=1.3)
task_kernel_train = 1. * SEKernel(length_scale=1.2) + WhiteNoiseKernel(noise=2.)
task_kernel_pred = deepcopy(task_kernel_train)

# %%
model = MagmaClust(k=nb_cluster, likelihood=BaseLikelihood(), prior_mean=ZeroMean(), mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=True, cluster_hp=True)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2026-03-02 12:56:30,436 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: 100.00 * SEKernel(length_scale=1.30)
# 	Task kernel: [1.00 ± 0.00]₄ * SEKernel(length_scale=[1.20 ± 0.00]₄) + WhiteNoiseKernel(noise=[2.00 ± 0.00]₄)
# 2026-03-02 12:56:32,133 - INFO - Iteration    1	Llhs:     199.1852,     547.3691	Conv. Ratio: inf
# 	Mean kernel: 100.00 * SEKernel(length_scale=1.32)
# 	Task kernel: [3.97 ± 1.19]₄ * SEKernel(length_scale=[0.87 ± 0.18]₄) + WhiteNoiseKernel(noise=[0.09 ± 0.07]₄)
# 2026-03-02 12:56:33,361 - INFO - Iteration    2	Llhs:     191.9493,     520.3271	Conv. Ratio: 0.04591
# 	Mean kernel: 100.00 * SEKernel(length_scale=1.34)
# 	Task kernel: [4.34 ± 1.63]₄ * SEKernel(length_scale=[1.01 ± 0.20]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.05]₄)
# 2026-03-02 12:56:33,429 - INFO - Iteration    3	Llhs:     120.6218,     508.0380	Conv. Ratio: 0.11739
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.45)
# 	Task kernel: [4.41 ± 1.77]₄ * SEKernel(length_scale=[1.07 ± 0.21]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,483 - INFO - Iteration    4	Llhs:     120.3497,     496.8668	Conv. Ratio: 0.01820
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.46)
# 	Task kernel: [4.31 ± 1.87]₄ * SEKernel(length_scale=[1.11 ± 0.21]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,556 - INFO - Iteration    5	Llhs:     117.9851,     492.2823	Conv. Ratio: 0.01126
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.47)
# 	Task kernel: [4.29 ± 1.91]₄ * SEKernel(length_scale=[1.13 ± 0.20]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,610 - INFO - Iteration    6	Llhs:     116.3899,     490.0414	Conv. Ratio: 0.00629
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.47)
# 	Task kernel: [4.28 ± 1.91]₄ * SEKernel(length_scale=[1.15 ± 0.19]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,661 - INFO - Iteration    7	Llhs:     115.2586,     488.9510	Conv. Ratio: 0.00366
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.47)
# 	Task kernel: [4.27 ± 1.92]₄ * SEKernel(length_scale=[1.16 ± 0.19]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,754 - INFO - Iteration    8	Llhs:     114.4469,     488.4057	Conv. Ratio: 0.00225
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.48)
# 	Task kernel: [4.27 ± 1.92]₄ * SEKernel(length_scale=[1.16 ± 0.18]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,813 - INFO - Iteration    9	Llhs:     113.8812,     488.0682	Conv. Ratio: 0.00150
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.48)
# 	Task kernel: [4.27 ± 1.92]₄ * SEKernel(length_scale=[1.17 ± 0.18]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)
# 2026-03-02 12:56:33,855 - INFO - Convergence reached after 10 iterations.	NLLs:     113.4230,     487.9922
# 	Mean kernel: 446.82 * SEKernel(length_scale=1.48)
# 	Task kernel: [4.27 ± 1.92]₄ * SEKernel(length_scale=[1.17 ± 0.18]₄) + WhiteNoiseKernel(noise=[0.07 ± 0.04]₄)

# %%
model.generate_grid(grid_size)
model.grid_pred.shape
# Out:
# (250, 1)

# %%
pred_means, pred_covs = model.predict()
pred_means.shape, pred_covs.shape
# Out:
# ((4, 4, 250), (4, 4, 250, 250))

# %% [markdown]
# ##### Test

# %%
model.plot_mean_processes()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %% [markdown]
# ---
