# %% [markdown]
# # Magma - Shared Input, Shared Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import kernax
kernax.config.parameter_transform = "softplus"  # Important for the stability of the optimisation
from kernax import WhiteNoiseKernel, SEKernel

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, Magma
# Out:
# INFO:2026-03-02 12:54:43,139:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2026-03-02 12:54:43,139 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(0)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %%
db = pd.read_csv(f"../../datasets/K=1/{test_db_size}_shared_input_shared_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kernel = 15. * SEKernel(length_scale=.5)
task_kernel_train = 5. * SEKernel(length_scale=1.2) + WhiteNoiseKernel(noise=2.)
task_kernel_pred = deepcopy(task_kernel_train)

prior_mean = ZeroMean()

likelihood = BaseLikelihood()

# %%
model = Magma(likelihood=likelihood, prior_mean=prior_mean, mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=True)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2026-03-02 12:54:44,370 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: 15.00 * SEKernel(length_scale=0.50)
# 	Task kernel: 5.00 * SEKernel(length_scale=1.20) + WhiteNoiseKernel(noise=2.00)
# 2026-03-02 12:54:45,549 - INFO - Iteration    1	Llhs:    -106.7641,     470.7045	Conv. Ratio: inf
# 	Mean kernel: 16.37 * SEKernel(length_scale=7.77)
# 	Task kernel: 6.84 * SEKernel(length_scale=1.45) + WhiteNoiseKernel(noise=0.30)
# 2026-03-02 12:54:46,333 - INFO - Iteration    2	Llhs:    -303.3625,     643.3464	Conv. Ratio: 0.06583
# 	Mean kernel: 19.29 * SEKernel(length_scale=8.45)
# 	Task kernel: 31.58 * SEKernel(length_scale=1.28) + WhiteNoiseKernel(noise=0.48)
# 2026-03-02 12:54:46,363 - INFO - Iteration    3	Llhs:    -523.8542,     665.4224	Conv. Ratio: 0.58360
# 	Mean kernel: 19.35 * SEKernel(length_scale=9.33)
# 	Task kernel: 43.84 * SEKernel(length_scale=1.39) + WhiteNoiseKernel(noise=0.53)
# 2026-03-02 12:54:46,382 - INFO - Iteration    4	Llhs:    -567.4918,     671.2983	Conv. Ratio: 0.26674
# 	Mean kernel: 19.35 * SEKernel(length_scale=9.33)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.43) + WhiteNoiseKernel(noise=0.55)
# 2026-03-02 12:54:46,393 - INFO - Iteration    5	Llhs:    -864.3413,     673.0506	Conv. Ratio: 2.84276
# 	Mean kernel: 19.85 * SEKernel(length_scale=11.74)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.44) + WhiteNoiseKernel(noise=0.55)
# 2026-03-02 12:54:46,404 - INFO - Iteration    6	Llhs:    -889.6335,     673.6821	Conv. Ratio: 0.12892
# 	Mean kernel: 19.85 * SEKernel(length_scale=11.74)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.43) + WhiteNoiseKernel(noise=0.55)
# 2026-03-02 12:54:46,416 - INFO - Iteration    7	Llhs:    -904.4405,     673.6552	Conv. Ratio: 0.06869
# 	Mean kernel: 19.87 * SEKernel(length_scale=11.80)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.43) + WhiteNoiseKernel(noise=0.55)
# 2026-03-02 12:54:46,424 - INFO - Iteration    8	Llhs:    -905.0752,     673.6863	Conv. Ratio: 0.00262
# 	Mean kernel: 19.87 * SEKernel(length_scale=11.80)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.43) + WhiteNoiseKernel(noise=0.55)
# 2026-03-02 12:54:46,434 - INFO - Convergence reached after 9 iterations.	NLLs:    -905.1161,     673.6912
# 	Mean kernel: 19.87 * SEKernel(length_scale=11.80)
# 	Task kernel: 48.43 * SEKernel(length_scale=1.43) + WhiteNoiseKernel(noise=0.55)

# %%
model.generate_grid(grid_size)
model.grid_pred.shape
# Out:
# (250, 1)

# %%
mean_pred, mean_cov = model.predict()
mean_pred.shape, mean_cov.shape
# Out:
# ((4, 250), (4, 250, 250))

# %%
model.plot_mean_process()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %%
model.plot_predictions(plot_as="samples", task_id=0, nb_samples=50)
plt.show()

# %% [markdown]
# ---
