# %% [markdown]
# # Magma - Distinct Input, Distinct Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import kernax
kernax.config.parameter_transform = "softplus"  # Important for the stability of the optimisation
from kernax import WhiteNoiseKernel, SEKernel

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, Magma
# Out:
# INFO:2026-03-02 13:02:42,852:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2026-03-02 13:02:42,852 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaClustPy/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(2)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %%
db = pd.read_csv(f"../../datasets/K=1/{test_db_size}_distinct_input_distinct_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /Users/simonlejoly/Documents/Work/MagmaClust/MagmaClustPy/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
from MagmaClustPy.custom_kernels import SEMagmaKernel
from kernax import ExpModule

mean_kernel = SEMagmaKernel(length_scale=1.5, variance=5.0)
task_kernel_train = SEMagmaKernel(length_scale=1.5, variance=3.0) + ExpModule(WhiteNoiseKernel(noise=2.))
task_kernel_pred = deepcopy(task_kernel_train)
# N.b: the HP values do not correspond : SEKernel and SEMagmaKernel have different parameterisations.

#mean_kernel = 15. * SEKernel(length_scale=1.5)
#task_kernel_train = 5. * SEKernel(length_scale=1.2) + WhiteNoiseKernel(noise=2.)
#task_kernel_pred = deepcopy(task_kernel_train)

prior_mean = ZeroMean()

likelihood = BaseLikelihood()

# %%
model = Magma(likelihood=likelihood, prior_mean=prior_mean, mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=False)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2026-03-02 13:02:44,111 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=1.25, _unconstrained_variance=4.99)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.25 ± 0.00]₁₆, _unconstrained_variance=[2.95 ± 0.00]₁₆) + Exp(WhiteNoiseKernel(noise=[2.00 ± 0.00]₁₆))
# 2026-03-02 13:02:45,841 - INFO - Iteration    1	Llhs:     923.2543,     576.7863	Conv. Ratio: inf
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=2.70, _unconstrained_variance=5.49)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.03 ± 2.16]₁₆, _unconstrained_variance=[10.68 ± 5.41]₁₆) + Exp(WhiteNoiseKernel(noise=[0.22 ± 0.24]₁₆))
# 2026-03-02 13:02:46,991 - INFO - Iteration    2	Llhs:   -2561.8837,     564.6240	Conv. Ratio: 2.33147
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=3.65, _unconstrained_variance=6.27)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.56 ± 2.45]₁₆, _unconstrained_variance=[11.26 ± 4.99]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.22]₁₆))
# 2026-03-02 13:02:47,051 - INFO - Iteration    3	Llhs:   -2402.7385,     570.8179	Conv. Ratio: 0.08278
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=3.65, _unconstrained_variance=6.27)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.35 ± 2.38]₁₆, _unconstrained_variance=[10.64 ± 4.64]₁₆) + Exp(WhiteNoiseKernel(noise=[0.21 ± 0.26]₁₆))
# 2026-03-02 13:02:47,195 - INFO - Iteration    4	Llhs:   -3629.5157,     570.7388	Conv. Ratio: 0.66971
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.14, _unconstrained_variance=6.51)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.31 ± 2.37]₁₆, _unconstrained_variance=[10.62 ± 4.65]₁₆) + Exp(WhiteNoiseKernel(noise=[0.21 ± 0.27]₁₆))
# 2026-03-02 13:02:47,315 - INFO - Iteration    5	Llhs:   -3484.5915,     572.7575	Conv. Ratio: 0.04804
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.14, _unconstrained_variance=6.51)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.13 ± 2.31]₁₆, _unconstrained_variance=[10.35 ± 4.52]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.29]₁₆))
# 2026-03-02 13:02:47,535 - INFO - Iteration    6	Llhs:   -3540.3270,     572.4214	Conv. Ratio: 0.01926
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.15, _unconstrained_variance=6.52)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.06 ± 2.29]₁₆, _unconstrained_variance=[10.22 ± 4.46]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.29]₁₆))
# 2026-03-02 13:02:47,597 - INFO - Iteration    7	Llhs:   -3547.0195,     572.1398	Conv. Ratio: 0.00235
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.15, _unconstrained_variance=6.52)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.05 ± 2.29]₁₆, _unconstrained_variance=[10.22 ± 4.46]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.29]₁₆))
# 2026-03-02 13:02:47,736 - INFO - Iteration    8	Llhs:   -3541.7098,     572.1711	Conv. Ratio: 0.00180
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.15, _unconstrained_variance=6.52)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.05 ± 2.29]₁₆, _unconstrained_variance=[10.22 ± 4.46]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.29]₁₆))
# 2026-03-02 13:02:47,819 - INFO - Iteration    9	Llhs:   -3748.8426,     572.1687	Conv. Ratio: 0.06975
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.27, _unconstrained_variance=6.57)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[2.05 ± 2.29]₁₆, _unconstrained_variance=[10.22 ± 4.46]₁₆) + Exp(WhiteNoiseKernel(noise=[0.20 ± 0.29]₁₆))
# 2026-03-02 13:02:47,879 - INFO - Iteration   10	Llhs:   -3732.5807,     572.5435	Conv. Ratio: 0.00524
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.27, _unconstrained_variance=6.57)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.88 ± 2.16]₁₆, _unconstrained_variance=[9.87 ± 4.18]₁₆) + Exp(WhiteNoiseKernel(noise=[0.19 ± 0.29]₁₆))
# 2026-03-02 13:02:48,021 - INFO - Iteration   11	Llhs:   -3827.3586,     571.4296	Conv. Ratio: 0.03035
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.31, _unconstrained_variance=6.58)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.88 ± 2.16]₁₆, _unconstrained_variance=[9.87 ± 4.18]₁₆) + Exp(WhiteNoiseKernel(noise=[0.19 ± 0.29]₁₆))
# 2026-03-02 13:02:48,061 - INFO - Iteration   12	Llhs:   -3821.4782,     571.5347	Conv. Ratio: 0.00184
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.31, _unconstrained_variance=6.58)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.87 ± 2.16]₁₆, _unconstrained_variance=[9.87 ± 4.18]₁₆) + Exp(WhiteNoiseKernel(noise=[0.19 ± 0.29]₁₆))
# 2026-03-02 13:02:48,174 - INFO - Iteration   13	Llhs:   -4631.6556,     571.5586	Conv. Ratio: 0.24928
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.78, _unconstrained_variance=6.76)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.87 ± 2.16]₁₆, _unconstrained_variance=[9.87 ± 4.18]₁₆) + Exp(WhiteNoiseKernel(noise=[0.19 ± 0.29]₁₆))
# 2026-03-02 13:02:48,300 - INFO - Iteration   14	Llhs:   -4668.4685,     570.9385	Conv. Ratio: 0.00922
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.78, _unconstrained_variance=6.76)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.47 ± 1.86]₁₆, _unconstrained_variance=[9.67 ± 3.99]₁₆) + Exp(WhiteNoiseKernel(noise=[0.11 ± 0.15]₁₆))
# 2026-03-02 13:02:48,376 - INFO - Iteration   15	Llhs:   -4653.1841,     570.7815	Conv. Ratio: 0.00369
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.78, _unconstrained_variance=6.76)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.45 ± 1.85]₁₆, _unconstrained_variance=[9.66 ± 3.97]₁₆) + Exp(WhiteNoiseKernel(noise=[0.11 ± 0.15]₁₆))
# 2026-03-02 13:02:48,421 - INFO - Convergence reached after 16 iterations.	NLLs:   -4649.6917,     570.8734
# 	Mean kernel: SEMagmaKernel(_unconstrained_length_scale=4.78, _unconstrained_variance=6.76)
# 	Task kernel: SEMagmaKernel(_unconstrained_length_scale=[1.45 ± 1.85]₁₆, _unconstrained_variance=[9.66 ± 3.97]₁₆) + Exp(WhiteNoiseKernel(noise=[0.11 ± 0.15]₁₆))

# %%
model.generate_grid(grid_size)
model.grid_pred.shape
# Out:
# (250, 1)

# %%
mean_pred, mean_cov = model.predict()
mean_pred.shape, mean_cov.shape
# Out:
# ((4, 250), (4, 250, 250))

# %%
model.plot_mean_process()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %%
model.plot_predictions(plot_as="samples", task_id=0, nb_samples=50)
plt.show()

# %% [markdown]
# ---
